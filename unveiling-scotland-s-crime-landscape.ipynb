# %% [markdown]
# <a href="https://www.kaggle.com/code/wabass/unveiling-scotland-s-crime-landscape?scriptVersionId=174719540" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/scottish-crimeoffences-in-2223/recorded-crime.csv

# %% [markdown]
# # **Report on Crime Data Analysis in Scottish Cities**
# The dataset provides comprehensive information on crime data for various cities across Scotland, categorizing different types of offences into eight groups. These groups include Non-sexual crimes of violence, Sexual crimes, Crimes of dishonesty, Damage and reckless behaviour, Crimes against society, Antisocial offences, Miscellaneous offences, and Road traffic offences. Each city's crime data is segmented into these categories, offering insights into the prevalence of different types of criminal activities.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt


data = pd.read_csv("/kaggle/input/scottish-crimeoffences-in-2223/recorded-crime.csv")

# %%
data.describe()
# Out:
#           All Crimes  All Group 1: Non-sexual crimes of violence  \
# count      33.000000                                   33.000000
# mean    17537.090909                                 4173.939394
# std     49788.042092                                11833.226607
# min       514.000000                                  135.000000
# 25%      3957.000000                                  907.000000
# 50%      5904.000000                                 1524.000000
# 75%     10094.000000                                 2536.000000
# max    289362.000000                                68870.000000
#
#        All Group 2: Sexual crimes  All Group 3: Crimes of dishonesty  \
# count                   33.000000                          33.000000
# mean                   884.969697                        6266.242424
# std                   2499.711502                       17856.135176
# min                     57.000000                         112.000000
# ...

# %% [markdown]
# # City Crime Ranking in Scotland

# %%
# City names and crime data
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']
crime_data = [ 14811, 8048, 4635, 3186, 32176, 2697, 7721, 12547, 6183, 2771, 4595, 2303, 7813, 20554, 50128, 10094, 4238, 4455, 3957, 820, 6852, 18751, 514, 5904, 9146, 4562, 637, 5418, 15769, 3680, 5180, 9217]

# Sorting cities and crime data in descending order
sorted_indices = sorted(range(len(crime_data)), key=lambda k: crime_data[k], reverse=False)
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data[i] for i in sorted_indices]

# Create horizontal bar chart
plt.figure(figsize=(10, 12))
plt.barh(sorted_cities, sorted_crime_data, color='Orange')
plt.xlabel('Number of Crimes')
plt.ylabel('City')
plt.title('City Crime Ranking in Scotland')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 1: Non-sexual crimes of violence

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 1
crime_data_group1 = np.array([3608, 2072, 1270, 866, 6939, 696, 1804, 2853, 1524, 548, 1138, 456, 1969, 5223, 11767, 2536, 791, 1088, 1209, 240, 1691, 4056, 135, 1570, 1945, 1308, 182, 1313, 3427, 907, 1221, 2518])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group1)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group1[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='red')
plt.xlabel('Cities')
plt.ylabel('Number of Crimes')
plt.title('Crime Ranking for "Group 1: Non-sexual crimes of violence" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 2: Sexual crimes

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 2
crime_data_group2 = np.array([731, 625, 382, 217, 1211, 120, 469, 519, 258, 135, 212, 111, 351, 1418, 2034, 744, 136, 212, 322, 57, 312, 966, 90, 396, 444, 253, 57, 219, 754, 192, 211, 444])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group2)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group2[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='Red')
plt.xlabel('Cities')
plt.ylabel('Number of Sexual Crimes')
plt.title('Crime Ranking for "Group 2: Sexual crimes" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 3: Crimes of dishonesty

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 3
crime_data_group3 = np.array([5449, 2447, 1645, 759, 14623, 894, 2114, 5383, 1930, 1142, 1667, 965, 2607, 8030, 17971, 2982, 1326, 1730, 954, 156, 2294, 5790, 112, 2106, 3301, 1350, 125, 2053, 5396, 1331, 1488, 3273])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group3)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group3[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='Red')
plt.xlabel('Cities')
plt.ylabel('Number of Crimes of Dishonesty')
plt.title('Crime Ranking for "Group 3: Crimes of dishonesty" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 4: Damage and Reckless Behaviour

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 4
crime_data_group4 = np.array([1983, 1188, 693, 501, 4461, 437, 1285, 1730, 1085, 393, 790, 413, 1430, 3126, 6160, 1573, 633, 783, 614, 109, 1146, 3188, 80, 800, 1336, 759, 78, 798, 2581, 561, 874, 1535])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group4)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group4[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='Red')
plt.xlabel('Cities')
plt.ylabel('Number of Damage and Reckless Behaviour Crimes')
plt.title('Crime Ranking for "Group 4: Damage and Reckless Behaviour" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 5: Crimes against Society

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 5
crime_data_group5 = np.array([3040, 1716, 645, 843, 4942, 550, 2049, 2062, 1386, 553, 788, 358, 1456, 2757, 12196, 2259, 1352, 642, 858, 258, 1409, 4751, 97, 1032, 2120, 892, 195, 1035, 3611, 689, 1386, 1447])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group5)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group5[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='Red')
plt.xlabel('Cities')
plt.ylabel('Number of Crimes against Society')
plt.title('Crime Ranking for "Group 5: Crimes against Society" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 6: Antisocial Offences

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 6
crime_data_group6 = np.array([1986, 980, 589, 804, 3957, 442, 1913, 1497, 1217, 391, 604, 398, 1338, 3356, 10597, 1540, 610, 624, 561, 114, 1355, 4163, 68, 782, 1617, 891, 118, 1111, 3235, 678, 1182, 1376])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group6)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group6[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='red')
plt.xlabel('Cities')
plt.ylabel('Number of Antisocial Offences')
plt.title('Crime Ranking for "Group 6: Antisocial Offences" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 7: Miscellaneous Offences

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 7
crime_data_group7 = np.array([540, 570, 222, 198, 969, 216, 462, 363, 295, 172, 192, 121, 487, 945, 1811, 441, 116, 271, 216, 43, 281, 769, 31, 511, 392, 289, 26, 225, 720, 174, 223, 502])

# Sort cities and crime data in descending order
sorted_indices = np.argsort(crime_data_group7)[::-1]
sorted_cities = [cities[i] for i in sorted_indices]
sorted_crime_data = [crime_data_group7[i] for i in sorted_indices]

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='red')
plt.xlabel('Cities')
plt.ylabel('Number of Miscellaneous Offences')
plt.title('Crime Ranking for "Group 7: Miscellaneous Offences" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Group 8: Road Traffic Offences

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for Group 8
crime_data_group8 = np.array([4162, 5719, 1788, 2319, 9091, 763, 6165, 2619, 2256, 808, 1358, 865, 2611, 6417, 16906, 7286, 920, 1531, 1551, 454, 2684, 6977, 608, 3667, 3360, 1772, 391, 1965, 4711, 1743, 3070, 2783])

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='red')
plt.xlabel('Cities')
plt.ylabel('Number of Road Traffic Offences')
plt.title('Crime Ranking for "Group 8: Road Traffic Offences" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Crime Ranking for All Offences

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for All Offences
crime_data_all_offences = np.array([6688, 7269, 2599, 3321, 14017, 1421, 8540, 4479, 3768, 1371, 2154, 1384, 4436, 10718, 29314, 9267, 1646, 2426, 2328, 611, 4320, 11909, 707, 4960, 5369, 2952, 535, 3301, 8666, 2595, 4475, 4661])

# Plot
plt.figure(figsize=(12, 8))
plt.bar(sorted_cities, sorted_crime_data, color='red')
plt.xlabel('Cities')
plt.ylabel('Number of All Offences')
plt.title('Crime Ranking for "All Offences" in Different Cities')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Top Ten Highest and Lowest Ranking Cities for All Offences

# %%
# City names
cities = ['Aberdeen City', 'Aberdeenshire', 'Angus', 'Argyll and Bute', 'City of Edinburgh', 'Clackmannanshire', 'Dumfries and Galloway', 'Dundee City', 'East Ayrshire', 'East Dunbartonshire', 'East Lothian', 'East Renfrewshire', 'Falkirk', 'Fife', 'Glasgow City', 'Highland', 'Inverclyde', 'Midlothian', 'Moray', 'Na h-Eileanan Siar', 'North Ayrshire', 'North Lanarkshire', 'Orkney Islands', 'Perth and Kinross', 'Renfrewshire', 'Scottish Borders', 'Shetland Islands', 'South Ayrshire', 'South Lanarkshire', 'Stirling', 'West Dunbartonshire', 'West Lothian']

# Crime data for All Offences
crime_data_all_offences = np.array([6688, 7269, 2599, 3321, 14017, 1421, 8540, 4479, 3768, 1371, 2154, 1384, 4436, 10718, 29314, 9267, 1646, 2426, 2328, 611, 4320, 11909, 707, 4960, 5369, 2952, 535, 3301, 8666, 2595, 4475, 4661])

# Sort cities and crime data in descending order
sorted_indices_descending = np.argsort(crime_data_all_offences)[::-1]
sorted_cities_descending = [cities[i] for i in sorted_indices_descending]
sorted_crime_data_descending = [crime_data_all_offences[i] for i in sorted_indices_descending]

# Top ten highest ranking cities
top_ten_highest_ranking_cities = sorted_cities_descending[:10]
top_ten_highest_ranking_crime_data = sorted_crime_data_descending[:10]

# Top ten lowest ranking cities
top_ten_lowest_ranking_cities = sorted_cities_descending[-10:]
top_ten_lowest_ranking_crime_data = sorted_crime_data_descending[-10:]

# Plot top ten highest ranking cities
plt.figure(figsize=(12, 6))
plt.bar(top_ten_highest_ranking_cities, top_ten_highest_ranking_crime_data, color='red')
plt.xlabel('City')
plt.ylabel('Number of Crimes')
plt.title('Top Ten Highest Ranking Cities for "All Offences"')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Plot top ten lowest ranking cities
plt.figure(figsize=(12, 6))
plt.bar(top_ten_lowest_ranking_cities, top_ten_lowest_ranking_crime_data, color='green')
plt.xlabel('City')
plt.ylabel('Number of Crimes')
plt.title('Top Ten Lowest Ranking Cities for "All Offences"')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Analysis:**
# 1. **Top Ten Highest Ranking Cities:**
#    - The analysis identified the top ten cities with the highest number of reported crimes under the category "All Offences".
#    - Glasgow City tops the list with a significantly higher number of reported crimes compared to other cities.
#    - Other cities in the top ten list include City of Edinburgh, North Lanarkshire, Fife, and Aberdeen City, among others.
#    - The bar chart visualizes the crime data for each city, highlighting Glasgow City as the city with the highest crime rate.
#
# 2. **Top Ten Lowest Ranking Cities:**
#    - Conversely, the analysis also identified the top ten cities with the lowest number of reported crimes under the category "All Offences".
#    - These cities exhibit relatively lower crime rates compared to the top-ranking cities.
#    - Orkney Islands, Na h-Eileanan Siar, and Shetland Islands are among the cities with the lowest crime rates.
#    - The bar chart illustrates the crime data for each city, emphasizing the comparatively lower crime rates in these regions.
#
# **Conclusion:**
# The analysis of crime data in Scottish cities reveals significant variations in crime rates across different regions. While some cities experience higher crime rates, others demonstrate relatively lower levels of criminal activity. Understanding these variations is crucial for policymakers and law enforcement agencies to develop targeted interventions and allocate resources effectively to address crime and ensure the safety and security of residents.
#
# Overall, this analysis provides valuable insights into the distribution of reported crimes across various cities in Scotland, serving as a basis for further research and policymaking efforts in the field of crime prevention and law enforcement.
